# %% [markdown]
# # Assignment 10: Pandas
# ### Series, Dataframe, Functions, Filtering & Analysis
#
# - Author: Nihit Kumar
# - Date: 2025-02-14
#
# [Assignment Source Link](https://docs.google.com/document/d/1FuwP71rVWezK6l9HsWrrCXpAFMWug5nQZpP1GtBHN3Y/edit?tab=t.0)
#
# ***

# %% [markdown]
# > **Task 1: Pandas Series Basics**

# %%
import pandas as pd

marks = [78,85,90,66,72]
marks_series = pd.Series(marks)

print("Series values:",marks_series.values)
print("Series Index:",marks_series.index)
print("Data Types:",marks_series.dtypes)
print("First Element:",marks_series[0])
print("Last two elements:",marks_series.values[-2:])
# Out:
# Series values: [78 85 90 66 72]
# Series Index: RangeIndex(start=0, stop=5, step=1)
# Data Types: int64
# First Element: 78
# Last two elements: [66 72]
